# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("features/train_features.csv")
d_test = pd.read_csv("features/test_features.csv")

# %%
data.describe()
# Out:
#          Unnamed: 0        tripid  additional_fare       duration  \
# count  17176.000000  1.717600e+04     16974.000000   17176.000000
# mean    8587.500000  2.014549e+08        13.719651    1713.276432
# std     4958.428447  7.456830e+06        98.975052    8101.692035
# min        0.000000  1.891236e+08         0.000000       0.000000
# 25%     4293.750000  1.947619e+08        10.500000     547.000000
# 50%     8587.500000  2.013582e+08        10.500000    1011.000000
# 75%    12881.250000  2.083081e+08        10.500000    1807.000000
# max    17175.000000  2.138173e+08     12795.030000  453872.000000
#
#        meter_waiting  meter_waiting_fare  meter_waiting_till_pickup  \
# count   16974.000000        16974.000000               16974.000000
# mean      629.074231           32.057666                 112.466832
# std      8063.260669          465.483573                 442.054812
# min         0.000000            0.000000                   0.000000
# ...

# %%
del data['Unnamed: 0']

# %%
data[data.meter_waiting>data.duration]
# Out:
#           tripid  additional_fare  duration  meter_waiting  \
# 30     189164806            10.50       780         2689.0
# 11049  205035393           450.82        68         1555.0
# 11952  206984071            10.50       780          833.0
# 12687  207947602            40.50        24          617.0
# 12898  208324987            10.50        65          774.0
# 13544  209203396            10.50       720         1905.0
# 14043  209365576         12795.03        40       210164.0
#
#        meter_waiting_fare  meter_waiting_till_pickup          pickup_time  \
# 30             146.985400                       69.0  2019-11-01 09:16:00
# 11049           90.656500                       65.0  2019-12-30 10:10:00
# 11952           48.147400                      169.0  2020-01-04 15:05:00
# 12687            0.000000                      229.0  2020-01-08 14:55:00
# 12898            0.000000                      108.0  2020-01-09 16:11:00
# ...

# %%
data = data.drop([30,11049, 12687, 12898, 13544, 14043])

# %%
data[data.meter_waiting>data.duration]
# Out:
#           tripid  additional_fare  duration  meter_waiting  \
# 11952  206984071             10.5       780          833.0
#
#        meter_waiting_fare  meter_waiting_till_pickup          pickup_time  \
# 11952             48.1474                      169.0  2020-01-04 15:05:00
#
#                  drop_time  pick_lat  pick_lon  ...  pickup_hour  \
# 11952  2020-01-04 15:18:00   6.91742    79.855  ...           15
#
#        pickup_minute  drop_year  drop_month  drop_date  drop_hour  \
# 11952              5       2020           1          4         15
#
#        drop_minute  seconds  number_of_nights  pickup_day
# 11952           18      780                 0           5
#
# [1 rows x 30 columns]

# %%
data = data.drop([11952])

# %%
d_test[d_test.meter_waiting>d_test.duration]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, tripid, additional_fare, duration, meter_waiting, meter_waiting_fare, meter_waiting_till_pickup, pickup_time, drop_time, pick_lat, pick_lon, drop_lat, drop_lon, fare, pickup_year, pickup_month, pickup_date, pickup_hour, pickup_minute, drop_year, drop_month, drop_date, drop_hour, drop_minute, number_of_nights, seconds, pickup_day, lat_diff, lon_diff, distance]
# Index: []
#
# [0 rows x 30 columns]

# %%
data[data.fare<data.additional_fare]
# Out:
#           tripid  additional_fare  duration  meter_waiting  \
# 10084  203757140            110.5       521           80.0
#
#        meter_waiting_fare  meter_waiting_till_pickup          pickup_time  \
# 10084            4.653641                       67.0  2019-12-24 17:07:00
#
#                  drop_time  pick_lat  pick_lon  ...  pickup_hour  \
# 10084  2019-12-24 17:15:00   7.29295    80.637  ...           17
#
#        pickup_minute  drop_year  drop_month  drop_date  drop_hour  \
# 10084              7       2019          12         24         17
#
#        drop_minute  seconds  number_of_nights  pickup_day
# 10084           15      480                 0           1
#
# [1 rows x 30 columns]

# %%
data.additional_fare[10084] =10.5
# Out:
# c:\users\isuru\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data[data.fare<data.additional_fare]
# Out:
# Empty DataFrame
# Columns: [tripid, additional_fare, duration, meter_waiting, meter_waiting_fare, meter_waiting_till_pickup, pickup_time, drop_time, pick_lat, pick_lon, drop_lat, drop_lon, fare, label, lat_diff, lon_diff, distance, pickup_year, pickup_month, pickup_date, pickup_hour, pickup_minute, drop_year, drop_month, drop_date, drop_hour, drop_minute, seconds, number_of_nights, pickup_day]
# Index: []
#
# [0 rows x 30 columns]

# %%
d_test[d_test.fare<d_test.additional_fare]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, tripid, additional_fare, duration, meter_waiting, meter_waiting_fare, meter_waiting_till_pickup, pickup_time, drop_time, pick_lat, pick_lon, drop_lat, drop_lon, fare, pickup_year, pickup_month, pickup_date, pickup_hour, pickup_minute, drop_year, drop_month, drop_date, drop_hour, drop_minute, number_of_nights, seconds, pickup_day, lat_diff, lon_diff, distance]
# Index: []
#
# [0 rows x 30 columns]

# %%
data[data.distance>5]
# Out:
#         tripid  additional_fare  duration  meter_waiting  meter_waiting_fare  \
# 920  190167541             10.5       313           50.0               2.915
#
#      meter_waiting_till_pickup          pickup_time            drop_time  \
# 920                       98.0  2019-11-06 09:37:00  2019-11-06 09:42:00
#
#      pick_lat  pick_lon  ...  pickup_hour  pickup_minute  drop_year  \
# 920   7.46897   80.6227  ...            9             37       2019
#
#      drop_month  drop_date  drop_hour  drop_minute  seconds  number_of_nights  \
# 920          11          6          9           42      300                 0
#
#      pickup_day
# 920           2
#
# [1 rows x 30 columns]

# %%
data = data.drop([920])

# %%
data[data.distance>5]
# Out:
# Empty DataFrame
# Columns: [tripid, additional_fare, duration, meter_waiting, meter_waiting_fare, meter_waiting_till_pickup, pickup_time, drop_time, pick_lat, pick_lon, drop_lat, drop_lon, fare, label, lat_diff, lon_diff, distance, pickup_year, pickup_month, pickup_date, pickup_hour, pickup_minute, drop_year, drop_month, drop_date, drop_hour, drop_minute, seconds, number_of_nights, pickup_day]
# Index: []
#
# [0 rows x 30 columns]

# %%
d_test[d_test.distance>5]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, tripid, additional_fare, duration, meter_waiting, meter_waiting_fare, meter_waiting_till_pickup, pickup_time, drop_time, pick_lat, pick_lon, drop_lat, drop_lon, fare, pickup_year, pickup_month, pickup_date, pickup_hour, pickup_minute, drop_year, drop_month, drop_date, drop_hour, drop_minute, number_of_nights, seconds, pickup_day, lat_diff, lon_diff, distance]
# Index: []
#
# [0 rows x 30 columns]

# %%
data[data.meter_waiting_fare>data.fare]
# Out:
# Empty DataFrame
# Columns: [tripid, additional_fare, duration, meter_waiting, meter_waiting_fare, meter_waiting_till_pickup, pickup_time, drop_time, pick_lat, pick_lon, drop_lat, drop_lon, fare, label, lat_diff, lon_diff, distance, pickup_year, pickup_month, pickup_date, pickup_hour, pickup_minute, drop_year, drop_month, drop_date, drop_hour, drop_minute, seconds, number_of_nights, pickup_day]
# Index: []
#
# [0 rows x 30 columns]

# %%
d_test[d_test.meter_waiting_fare>d_test.fare]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, tripid, additional_fare, duration, meter_waiting, meter_waiting_fare, meter_waiting_till_pickup, pickup_time, drop_time, pick_lat, pick_lon, drop_lat, drop_lon, fare, pickup_year, pickup_month, pickup_date, pickup_hour, pickup_minute, drop_year, drop_month, drop_date, drop_hour, drop_minute, number_of_nights, seconds, pickup_day, lat_diff, lon_diff, distance]
# Index: []
#
# [0 rows x 30 columns]

# %%
d_test.describe()
# Out:
#         Unnamed: 0        tripid  additional_fare       duration  \
# count  8576.000000  8.576000e+03      8576.000000    8576.000000
# mean   4287.500000  2.180067e+08        11.088095    1541.580340
# std    2475.822288  2.789252e+06         5.359602    5952.459798
# min       0.000000  2.132846e+08         0.000000       0.000000
# 25%    2143.750000  2.156247e+08        10.500000     540.000000
# 50%    4287.500000  2.179006e+08        10.500000     982.500000
# 75%    6431.250000  2.203904e+08        10.500000    1723.000000
# max    8575.000000  2.228607e+08       160.500000  447230.000000
#
#        meter_waiting  meter_waiting_fare  meter_waiting_till_pickup  \
# count    8576.000000         8576.000000                8576.000000
# mean      508.502099           24.671655                 119.863106
# std      5784.005855          333.515641                 793.233190
# min         0.000000            0.000000                   0.000000
# ...

# %%
data.describe()
# Out:
#              tripid  additional_fare       duration  meter_waiting  \
# count  1.716800e+04     16966.000000   17168.000000   16966.000000
# mean   2.014541e+08        12.934015    1713.912279     616.487033
# std    7.456482e+06        12.603817    8103.522859    7903.055395
# min    1.891236e+08         0.000000       0.000000       0.000000
# 25%    1.947619e+08        10.500000     547.000000      33.000000
# 50%    2.013573e+08        10.500000    1012.000000     123.000000
# 75%    2.083017e+08        10.500000    1808.000000     351.000000
# max    2.138173e+08       221.000000  453872.000000  453650.000000
#
#        meter_waiting_fare  meter_waiting_till_pickup      pick_lat  \
# count        16966.000000               16966.000000  17168.000000
# mean            31.327089                 112.464282      6.965443
# std            456.039691                 442.156762      0.210731
# min              0.000000                   0.000000      5.937600
# ...

# %%
data.to_csv("Outliers_Handling/train_features.csv")
d_test.to_csv("Outliers_Handling/test_features.csv")
