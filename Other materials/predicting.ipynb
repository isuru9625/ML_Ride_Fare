# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("train.csv")

# %%
data.describe()
# Out:
#              tripid  additional_fare       duration  meter_waiting  \
# count  1.717600e+04     16974.000000   17176.000000   16974.000000
# mean   2.014549e+08        13.719651    1713.634898     629.074231
# std    7.456830e+06        98.975052    8101.696673    8063.260669
# min    1.891236e+08         0.000000       0.000000       0.000000
# 25%    1.947619e+08        10.500000     547.000000      33.000000
# 50%    2.013582e+08        10.500000    1012.000000     123.000000
# 75%    2.083081e+08        10.500000    1808.000000     351.000000
# max    2.138173e+08     12795.030000  453872.000000  453650.000000
#
#        meter_waiting_fare  meter_waiting_till_pickup      pick_lat  \
# count        16974.000000               16974.000000  17176.000000
# mean            32.057666                 112.466832      6.965499
# std            465.483573                 442.054812      0.210760
# min              0.000000                   0.000000      5.937600
# ...

# %%
  data[data.additional_fare>1000]
# Out:
# Empty DataFrame
# Columns: [tripid, additional_fare, duration, meter_waiting, meter_waiting_fare, meter_waiting_till_pickup, pickup_time, drop_time, pick_lat, pick_lon, drop_lat, drop_lon, fare, label]
# Index: []

# %%
data.drop([14043],inplace =True)

# %%
data[14040:14045]
# Out:
#           tripid  additional_fare  duration  meter_waiting  \
# 14040  209974687             10.5      2684         1311.0
# 14041  209976047             10.5        39           36.0
# 14042  209977801             30.5      1038           94.0
# 14044  209980452             10.5       668          108.0
# 14045  209981901             10.5     31921         8364.0
#
#        meter_waiting_fare  meter_waiting_till_pickup     pickup_time  \
# 14040             75.7758                       46.0  1/16/2020 0:44
# 14041              2.0988                       88.0  1/16/2020 2:05
# 14042              5.4802                        8.0  1/16/2020 4:57
# 14044              0.0000                       64.0  1/16/2020 6:14
# 14045            483.4392                       38.0  1/16/2020 6:27
#
#              drop_time  pick_lat  pick_lon  drop_lat  drop_lon     fare  label
# 14040   1/16/2020 1:29   6.94979   79.9278   7.00123   79.9087   439.62      1
# ...

# %%
data.describe()
# Out:
#              tripid  additional_fare       duration  meter_waiting  \
# count  1.717500e+04     16973.000000   17175.000000   16973.000000
# mean   2.014545e+08        12.966613    1713.732344     616.729040
# std    7.456803e+06        13.065004    8101.922475    7901.452393
# min    1.891236e+08         0.000000       0.000000       0.000000
# 25%    1.947617e+08        10.500000     547.000000      33.000000
# 50%    2.013575e+08        10.500000    1012.000000     123.000000
# 75%    2.083038e+08        10.500000    1808.000000     351.000000
# max    2.138173e+08       450.820000  453872.000000  453650.000000
#
#        meter_waiting_fare  meter_waiting_till_pickup      pick_lat  \
# count        16973.000000               16973.000000  17175.000000
# mean            31.337669                 112.462735      6.965488
# std            455.947327                 442.067513      0.210761
# min              0.000000                   0.000000      5.937600
# ...

# %%
data.additional_fare.hist()

# %%
data[data.duration<data.meter_waiting]
# Out:
#           tripid  additional_fare  duration  meter_waiting  \
# 11049  205035393           450.82        68         1555.0
# 12687  207947602            40.50        24          617.0
# 12898  208324987            10.50        65          774.0
#
#        meter_waiting_fare  meter_waiting_till_pickup       pickup_time  \
# 11049             90.6565                       65.0  12/30/2019 10:10
# 12687              0.0000                      229.0    1/8/2020 14:55
# 12898              0.0000                      108.0    1/9/2020 16:11
#
#               drop_time  pick_lat  pick_lon  drop_lat  drop_lon    fare  label
# 11049  12/30/2019 10:12   7.47655   80.3588   7.48167   80.3607  591.47      0
# 12687    1/8/2020 14:56   6.93383   79.8545   6.93317   79.8556   90.50      1
# 12898    1/9/2020 16:12   6.91368   79.9714   6.91061   79.9717   60.50      0

# %%
data.drop([11049,12687,12898], inplace = True)

# %%
data[data.duration<data.meter_waiting]
# Out:
# Empty DataFrame
# Columns: [tripid, additional_fare, duration, meter_waiting, meter_waiting_fare, meter_waiting_till_pickup, pickup_time, drop_time, pick_lat, pick_lon, drop_lat, drop_lon, fare, label]
# Index: []

# %%
data[data.fare<data.additional_fare]
# Out:
#           tripid  additional_fare  duration  meter_waiting  \
# 10084  203757140            110.5       521           80.0
#
#        meter_waiting_fare  meter_waiting_till_pickup       pickup_time  \
# 10084            4.653641                       67.0  12/24/2019 17:07
#
#               drop_time  pick_lat  pick_lon  drop_lat  drop_lon   fare  label
# 10084  12/24/2019 17:15   7.29295    80.637   7.28589   80.6319  77.51      1

# %%
data.additional_fare[10084] = 10.5
# Out:
# c:\users\isuru\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data[data.fare<data.additional_fare]
# Out:
# Empty DataFrame
# Columns: [tripid, additional_fare, duration, meter_waiting, meter_waiting_fare, meter_waiting_till_pickup, pickup_time, drop_time, pick_lat, pick_lon, drop_lat, drop_lon, fare, label]
# Index: []

# %%
data[data.fare<data.meter_waiting_fare]
# Out:
# Empty DataFrame
# Columns: [tripid, additional_fare, duration, meter_waiting, meter_waiting_fare, meter_waiting_till_pickup, pickup_time, drop_time, pick_lat, pick_lon, drop_lat, drop_lon, fare, label]
# Index: []

# %%
data.describe()
# Out:
#              tripid  additional_fare       duration  meter_waiting  \
# count  1.717200e+04     16970.000000   17172.000000   16970.000000
# mean   2.014535e+08        12.933441    1714.022595     616.664467
# std    7.457055e+06        12.602387    8102.600431    7902.147447
# min    1.891236e+08         0.000000       0.000000       0.000000
# 25%    1.947611e+08        10.500000     547.750000      33.000000
# 50%    2.013573e+08        10.500000    1012.000000     123.000000
# 75%    2.083017e+08        10.500000    1808.000000     351.000000
# max    2.138173e+08       221.000000  453872.000000  453650.000000
#
#        meter_waiting_fare  meter_waiting_till_pickup      pick_lat  \
# count        16970.000000               16970.000000  17172.000000
# mean            31.337867                 112.458928      6.965463
# std            455.987275                 442.105532      0.210743
# min              0.000000                   0.000000      5.937600
# ...

# %%
data[data.meter_waiting_till_pickup>3600]
# Out:
#           tripid  additional_fare  duration  meter_waiting  \
# 1761   191056435             10.5        80           80.0
# 2955   192666104             10.5      3966         1212.0
# 3365   193341290             10.5    154423       121319.0
# 3690   193827380             10.5        83           73.0
# 7872   200235706             10.5        53           53.0
# 11353  205639292             10.5        98            0.0
# 15292  211428449             10.5        39           39.0
#
#        meter_waiting_fare  meter_waiting_till_pickup       pickup_time  \
# 1761               0.0000                    51288.0  11/10/2019 09:59
# 2955               0.0000                     5600.0   11/18/2019 7:48
# 3365            7012.2382                    11722.0  11/20/2019 15:52
# 3690               0.0000                     8800.0  11/22/2019 12:36
# 7872               3.0899                     4620.0  12/13/2019 14:44
# ...

# %%
data.drop([3365], inplace = True)

# %%
data[data.meter_waiting_till_pickup>3600]
# Out:
#           tripid  additional_fare  duration  meter_waiting  \
# 1761   191056435             10.5        80           80.0
# 2955   192666104             10.5      3966         1212.0
# 3690   193827380             10.5        83           73.0
# 7872   200235706             10.5        53           53.0
# 11353  205639292             10.5        98            0.0
# 15292  211428449             10.5        39           39.0
#
#        meter_waiting_fare  meter_waiting_till_pickup       pickup_time  \
# 1761               0.0000                    51288.0  11/10/2019 09:59
# 2955               0.0000                     5600.0   11/18/2019 7:48
# 3690               0.0000                     8800.0  11/22/2019 12:36
# 7872               3.0899                     4620.0  12/13/2019 14:44
# 11353              0.0000                    11944.0    1/1/2020 00:28
# 15292              2.2737                     4092.0   1/22/2020 15:11
#
# ...

# %%
data[data.duration==data.meter_waiting]
# Out:
#           tripid  additional_fare  duration  meter_waiting  \
# 1761   191056435             10.5        80           80.0
# 2700   192182656              5.0        23           23.0
# 3549   193653017              0.0         0            0.0
# 4785   195445714             10.5        27           27.0
# 5540   197020223             10.5        49           49.0
# 5770   197271380             10.5        29           29.0
# 6061   197546607             10.5        28           28.0
# 7166   199104080             21.0        49           49.0
# 7872   200235706             10.5        53           53.0
# 10160  203915670             10.5      1300         1300.0
# 15122  211275614             10.5        61           61.0
# 15292  211428449             10.5        39           39.0
# 16085  212290406             10.5        38           38.0
# 16742  213112837              0.0         0            0.0
#
#        meter_waiting_fare  meter_waiting_till_pickup       pickup_time  \
# ...

# %%
data.drop([3549,16742], inplace = True)

# %%
data[data.duration==data.meter_waiting]
# Out:
#           tripid  additional_fare  duration  meter_waiting  \
# 1761   191056435             10.5        80           80.0
# 2700   192182656              5.0        23           23.0
# 4785   195445714             10.5        27           27.0
# 5540   197020223             10.5        49           49.0
# 5770   197271380             10.5        29           29.0
# 6061   197546607             10.5        28           28.0
# 7166   199104080             21.0        49           49.0
# 7872   200235706             10.5        53           53.0
# 10160  203915670             10.5      1300         1300.0
# 15122  211275614             10.5        61           61.0
# 15292  211428449             10.5        39           39.0
# 16085  212290406             10.5        38           38.0
#
#        meter_waiting_fare  meter_waiting_till_pickup       pickup_time  \
# 1761               0.0000                    51288.0  11/10/2019 09:59
# ...

# %%
data.drop([1761], inplace = True)

# %%
data[data.duration==data.meter_waiting]
# Out:
#           tripid  additional_fare  duration  meter_waiting  \
# 4785   195445714             10.5        27           27.0
# 5540   197020223             10.5        49           49.0
# 5770   197271380             10.5        29           29.0
# 6061   197546607             10.5        28           28.0
# 7166   199104080             21.0        49           49.0
# 7872   200235706             10.5        53           53.0
# 10160  203915670             10.5      1300         1300.0
# 15122  211275614             10.5        61           61.0
# 15292  211428449             10.5        39           39.0
# 16085  212290406             10.5        38           38.0
#
#        meter_waiting_fare  meter_waiting_till_pickup       pickup_time  \
# 4785               0.0000                       85.0  11/27/2019 18:50
# 5540               2.8567                       30.0   12/1/2019 17:21
# 5770               0.0000                       67.0   12/2/2019 19:17
# ...

# %%
data.duration[2700] = 230
# Out:
# c:\users\isuru\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data[data.duration ==0]
# Out:
#           tripid  additional_fare  duration  meter_waiting  \
# 1447   190793611              NaN         0            NaN
# 8275   200954474              NaN         0            NaN
# 10828  204722452              NaN         0            NaN
# 15044  211181044              NaN         0            NaN
# 15153  211315250              NaN         0            NaN
# 15697  211886110              NaN         0            NaN
#
#        meter_waiting_fare  meter_waiting_till_pickup       pickup_time  \
# 1447                  NaN                        NaN   11/8/2019 17:55
# 8275                  NaN                        NaN  12/15/2019 16:20
# 10828                 NaN                        NaN  12/28/2019 18:01
# 15044                 NaN                        NaN   1/21/2020 13:14
# 15153                 NaN                        NaN   1/21/2020 21:18
# 15697                 NaN                        NaN   1/24/2020 13:52
#
# ...

# %%
data.drop([1447,8275,10828,15044,15153,15697], inplace = True)

# %%
data[data.duration ==0]
# Out:
# Empty DataFrame
# Columns: [tripid, additional_fare, duration, meter_waiting, meter_waiting_fare, meter_waiting_till_pickup, pickup_time, drop_time, pick_lat, pick_lon, drop_lat, drop_lon, fare, label]
# Index: []

# %%
df = data[data.meter_waiting ==0]

# %%
df[df.meter_waiting_fare!=0]
# Out:
# Empty DataFrame
# Columns: [tripid, additional_fare, duration, meter_waiting, meter_waiting_fare, meter_waiting_till_pickup, pickup_time, drop_time, pick_lat, pick_lon, drop_lat, drop_lon, fare, label]
# Index: []

# %%
data[data.duration==data.meter_waiting]
# Out:
#           tripid  additional_fare  duration  meter_waiting  \
# 4785   195445714             10.5        27           27.0
# 5540   197020223             10.5        49           49.0
# 5770   197271380             10.5        29           29.0
# 6061   197546607             10.5        28           28.0
# 7166   199104080             21.0        49           49.0
# 7872   200235706             10.5        53           53.0
# 10160  203915670             10.5      1300         1300.0
# 15122  211275614             10.5        61           61.0
# 15292  211428449             10.5        39           39.0
# 16085  212290406             10.5        38           38.0
#
#        meter_waiting_fare  meter_waiting_till_pickup       pickup_time  \
# 4785               0.0000                       85.0  11/27/2019 18:50
# 5540               2.8567                       30.0   12/1/2019 17:21
# 5770               0.0000                       67.0   12/2/2019 19:17
# ...

# %%
dm = pd.read_csv("test.csv")

# %%
dm[dm.fare<=dm.meter_waiting_fare]
# Out:
#          tripid  additional_fare  duration  meter_waiting  meter_waiting_fare  \
# 1735  215137901              0.0         0              0                 0.0
# 3519  217137218              0.0      1934            115                 0.0
#
#       meter_waiting_till_pickup      pickup_time        drop_time  pick_lat  \
# 1735                        691  2/10/2020 12:45  2/10/2020 13:22   6.91339
# 3519                        353   2/19/2020 7:12   2/19/2020 7:44   6.72019
#
#       pick_lon  drop_lat  drop_lon  fare
# 1735   79.8977   6.87683   79.8605   0.0
# 3519   79.9389   6.71720   79.9930   0.0

# %%
data[data.fare==0]
# Out:
#           tripid  additional_fare  duration  meter_waiting  \
# 2141   191444740              0.0      2505          538.0
# 2415   191838640              0.0      1404          310.0
# 2418   191840284              0.0      2699          340.0
# 2419   191841099              0.0      2446          840.0
# 2420   191839931              0.0      1837          194.0
# 2421   191838505              0.0      2652          326.0
# 2422   191847685              0.0      2225          349.0
# 2428   191857740              0.0      2260          232.0
# 2450   191873008              0.0       861           28.0
# 4412   194990431              0.0      1966          278.0
# 6785   198719638              0.0       991          187.0
# 13797  209713807              0.0      2058          339.0
#
#        meter_waiting_fare  meter_waiting_till_pickup       pickup_time  \
# 2141                  0.0                      163.0  11/12/2019 16:14
# ...

# %%
dm[dm.fare==0]
# Out:
#          tripid  additional_fare  duration  meter_waiting  meter_waiting_fare  \
# 1735  215137901              0.0         0              0                 0.0
# 3519  217137218              0.0      1934            115                 0.0
#
#       meter_waiting_till_pickup      pickup_time        drop_time  pick_lat  \
# 1735                        691  2/10/2020 12:45  2/10/2020 13:22   6.91339
# 3519                        353   2/19/2020 7:12   2/19/2020 7:44   6.72019
#
#       pick_lon  drop_lat  drop_lon  fare
# 1735   79.8977   6.87683   79.8605   0.0
# 3519   79.9389   6.71720   79.9930   0.0

# %%
dm.describe()
# Out:
#              tripid  additional_fare       duration  meter_waiting  \
# count  8.576000e+03      8576.000000    8576.000000    8576.000000
# mean   2.180067e+08        11.088095    1541.590485     508.502099
# std    2.789252e+06         5.359602    5952.458574    5784.005855
# min    2.132846e+08         0.000000       0.000000       0.000000
# 25%    2.156247e+08        10.500000     540.000000      30.000000
# 50%    2.179006e+08        10.500000     982.500000     116.000000
# 75%    2.203904e+08        10.500000    1723.000000     336.250000
# max    2.228607e+08       160.500000  447230.000000  446934.000000
#
#        meter_waiting_fare  meter_waiting_till_pickup     pick_lat  \
# count         8576.000000                8576.000000  8576.000000
# mean            24.671655                 119.863106     6.969246
# std            333.515641                 793.233190     0.217809
# min              0.000000                   0.000000     5.943130
# ...

# %%
data[data.duration<data.meter_waiting_till_pickup]
# Out:
#           tripid  additional_fare  duration  meter_waiting  \
# 10     189135814             10.5        26           19.0
# 11     189140969             10.5        31           20.0
# 63     189192436             10.5        22           21.0
# 131    189255640             10.5        38           20.0
# 175    189326852             10.5        41           35.0
# 246    189387360             10.5        33           20.0
# 279    189415734             10.5        25           10.0
# 287    189416745             60.5        72           33.0
# 353    189619335             10.5        69           65.0
# 361    189625719             10.5       299           55.0
# 418    189685055             10.5        27            0.0
# 448    189737409             10.5       507           40.0
# 451    189734544             10.5        43           34.0
# 472    189767527             10.5       113            0.0
# 485    189789182             10.5        29           20.0
# ...

# %%
dm[dm.fare<dm.additional_fare+dm.meter_waiting_fare]
# Out:
#          tripid  additional_fare  duration  meter_waiting  meter_waiting_fare  \
# 8273  220092084             30.5      3062           1676             75.6602
#
#       meter_waiting_till_pickup      pickup_time        drop_time  pick_lat  \
# 8273                         38  3/14/2020 12:42  3/14/2020 13:34   6.87283
#
#       pick_lon  drop_lat  drop_lon    fare
# 8273   79.8644     6.845   79.9261  105.98

# %%
dm[dm.fare>10000]
# Out:
#          tripid  additional_fare  duration  meter_waiting  meter_waiting_fare  \
# 1514  214917319             10.5    165634         164927           9475.8476
# 1826  215172183             10.5    447230         446934          25760.3618
#
#       meter_waiting_till_pickup      pickup_time       drop_time  pick_lat  \
# 1514                         44    2/9/2020 8:09  2/11/2020 6:09   6.86683
# 1826                        142  2/10/2020 20:11  2/16/2020 0:25   6.89520
#
#       pick_lon  drop_lat  drop_lon      fare
# 1514   79.9224   6.72286   79.9304  10479.48
# 1826   79.8686   6.72823   79.9319  26844.33

# %%
data[data.meter_waiting_till_pickup==0]
# Out:
#           tripid  additional_fare  duration  meter_waiting  \
# 23     189159951              5.0       850          143.0
# 32     189165701              5.0      1588          302.0
# 55     189184874              5.0      2710          820.0
# 58     189189239              5.0      1144          230.0
# 64     189195252              5.0       245           60.0
# 68     189199402              5.0       466           52.0
# 70     189200722              5.0       592          394.0
# 74     189213407              5.0    162747       162277.0
# 75     189214033              5.0       189           10.0
# 82     189228044              5.0      1255          570.0
# 87     189230734              5.0        99           10.0
# 90     189231083             10.5       462           30.0
# 103    189245966              5.0       382           28.0
# 142    189299614              5.0       318           27.0
# 147    189302363              5.0        86           83.0
# ...

# %%
data[data.fare-data.additional_fare-data.meter_waiting_fare>1000]
# Out:
#           tripid  additional_fare  duration  meter_waiting  \
# 5      189129552             10.5      3407          182.0
# 62     189191865             10.5      3813         2090.0
# 114    189252401             10.5      3216          810.0
# 213    189363308             10.5      5928         1447.0
# 362    189626199             10.5       564           44.0
# 410    189663502             10.5      3675          222.0
# 458    189747601             10.5      4209         1726.0
# 486    189800308             10.5     20699        12954.0
# 591    189879609             10.5      4491          470.0
# 628    189925207             10.5      5233          288.0
# 694    189989861              5.0     77211        64397.0
# 726    190007029              5.0      8529         3590.0
# 759    190023371             10.5      7185         2190.0
# 1072   190292867             10.5      4414         1366.0
# 1078   190296648             10.5      4087          280.0
# ...

# %%
 l = dm[dm.fare-dm.additional_fare-dm.meter_waiting_fare>1000]

# %%
l[l.duration<1000]
# Out:
#          tripid  additional_fare  duration  meter_waiting  meter_waiting_fare  \
# 13    213310068             10.5       368              3                 0.0
# 1209  214574943             10.5       390             58                 0.0
# 3821  217426346             10.5       902             15                 0.0
# 4165  217795064             10.5       903            174                 0.0
# 4429  218031641             10.5       375             75                 0.0
#
#       meter_waiting_till_pickup      pickup_time        drop_time  pick_lat  \
# 13                          143    2/1/2020 8:34    2/1/2020 8:40   6.88865
# 1209                        212   2/7/2020 14:14   2/7/2020 14:20   7.22042
# 3821                        142  2/20/2020 13:10  2/20/2020 13:25   7.03357
# 4165                         56   2/22/2020 8:58   2/22/2020 9:13   7.49796
# 4429                         59  2/23/2020 18:47  2/23/2020 18:53   6.93525
#
# ...

# %%
data[data.meter_waiting_till_pickup>10000]
# Out:
#           tripid  additional_fare  duration  meter_waiting  \
# 11353  205639292             10.5        98            0.0
#
#        meter_waiting_fare  meter_waiting_till_pickup     pickup_time  \
# 11353                 0.0                    11944.0  1/1/2020 00:28
#
#             drop_time  pick_lat  pick_lon  drop_lat  drop_lon  fare  label
# 11353  1/1/2020 00:30   6.92052    79.863   6.95198   79.8609  60.5      1

# %%
data[data.fare ==0]
# Out:
#           tripid  additional_fare  duration  meter_waiting  \
# 2141   191444740              0.0      2505          538.0
# 2415   191838640              0.0      1404          310.0
# 2418   191840284              0.0      2699          340.0
# 2419   191841099              0.0      2446          840.0
# 2420   191839931              0.0      1837          194.0
# 2421   191838505              0.0      2652          326.0
# 2422   191847685              0.0      2225          349.0
# 2428   191857740              0.0      2260          232.0
# 2450   191873008              0.0       861           28.0
# 4412   194990431              0.0      1966          278.0
# 6785   198719638              0.0       991          187.0
# 13797  209713807              0.0      2058          339.0
#
#        meter_waiting_fare  meter_waiting_till_pickup       pickup_time  \
# 2141                  0.0                      163.0  11/12/2019 16:14
# ...

# %%
dm[dm.fare ==0]
# Out:
#          tripid  additional_fare  duration  meter_waiting  meter_waiting_fare  \
# 1735  215137901              0.0         0              0                 0.0
# 3519  217137218              0.0      1934            115                 0.0
#
#       meter_waiting_till_pickup      pickup_time        drop_time  pick_lat  \
# 1735                        691  2/10/2020 12:45  2/10/2020 13:22   6.91339
# 3519                        353   2/19/2020 7:12   2/19/2020 7:44   6.72019
#
#       pick_lon  drop_lat  drop_lon  fare
# 1735   79.8977   6.87683   79.8605   0.0
# 3519   79.9389   6.71720   79.9930   0.0

# %%
data[data.duration>2000]
# Out:
#           tripid  additional_fare  duration  meter_waiting  \
# 5      189129552             10.5      3407          182.0
# 12     189144528             10.5      2011          199.0
# 15     189146174             10.5      4221         1608.0
# 18     189151585             10.5      2435          381.0
# 20     189157607             10.5      2956         1686.0
# 21     189157476             10.5      3176          390.0
# 30     189164806             10.5      3549         2689.0
# 33     189165828             10.5      2523          140.0
# 40     189170751             10.5      2847          865.0
# 45     189176766             10.5      7008         6120.0
# 53     189182263             10.5      2225          310.0
# 55     189184874              5.0      2710          820.0
# 59     189188700             10.5      2221          628.0
# 62     189191865             10.5      3813         2090.0
# 72     189207229             10.5      2412          190.0
# ...
